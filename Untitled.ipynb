# %% [markdown]
# # Inlämning 6 programmering och AI

# %% [markdown]
# # version check

# %%
import sys
import numpy as np
import pandas as pd
import sklearn
print("Python version:", sys.version)
print("Numpy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Scikit-learn version:", sklearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import sys
# ----> 2 import numpy as np
#       3 import pandas as pd
#       4 import sklearn
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# for plots to appear nicely in notebooks
# %matplotlib inline

# %% [markdown]
# # Ladda in datan

# %%
column_names = [
    "tau1",
    "tau2",
    "tau3",
    "tau4",
    "p1",
    "p2",
    "p3",
    "p4",
    "g1",
    "g2",
    "g3",
    "g4"
]

df = pd.read_csv("grid_stability.csv", header=0, names=column_names)

df.head()
# Out:
#                         tau1      tau2      tau3      tau4        p1  \
# 6.600845 8.255092   8.134127  4.439502  4.338452 -1.075825 -1.368758
# 0.672406 0.767250   5.557320  3.745670       NaN -1.058568 -1.178951
# 4.774847 8.886962   1.753138  9.834987  5.232961 -1.962825 -1.707114
# 3.385400 8.481287   8.662505  2.248601  3.349981 -1.188818       NaN
# 7.574847 32.692856  6.202064  6.531809  3.222619 -1.430452 -0.591138
#
#                           p2        p3        p4        g1        g2  \
# 6.600845 8.255092  -1.885294  0.166416  0.610676  0.794066  0.836081
# 0.672406 0.767250  -0.688745  0.739582  0.772502  0.419886  0.840959
# 4.774847 8.886962  -1.567117  0.849548  0.598998  0.302801  0.127460
# 3.385400 8.481287  -1.105990  0.964002  0.683728  0.443628  0.689983
# 7.574847 32.692856 -1.195414  0.219404  0.680077       NaN  0.726814
#
#                           g3        g4
# 6.600845 8.255092   0.063720  unstable
# 0.672406 0.767250  -0.047254    stable
# 4.774847 8.886962   0.014128  unstable
# 3.385400 8.481287   0.024980  unstable
# 7.574847 32.692856  0.050475  unstable

# %%
df.sample(10)
# Out:
#                        tau1      tau2       tau3      tau4        p1  \
# 7.355533 1.752923  8.894489  0.897446   3.361916 -0.877662       NaN
# 1.203128 4.944500  6.803087  5.761592  11.291166 -0.634683       NaN
# 0.904904 5.194450  0.618592  5.016766   4.747448 -1.752988 -1.057135
# 5.125565 2.549937  6.487319  4.980102   4.830510 -1.153270 -1.677654
# 8.480801 7.858174  0.905686  2.920552   3.624173 -0.542096 -1.403925
# 1.189970 8.497401  7.062890  2.491966   4.444533 -1.793347 -1.492149
# 7.689701 6.970272  3.530527  9.149792   4.013548 -1.310388 -1.659495
# 0.987496 4.400810  2.760912  9.592013   4.782851 -1.682975 -1.299439
# 8.571008 6.449375  1.065041  7.627844        NaN -1.406578 -1.661775
# 7.599809 7.505120  6.273664  9.738048   3.348379 -1.129246 -0.661166
#
#                          p2        p3        p4        g1        g2        g3  \
# 7.355533 1.752923 -1.332493  0.742247  0.965155       NaN       NaN -0.041268
# 1.203128 4.944500 -1.851594  0.994784  0.578443  0.975006  0.618860  0.048650
# 0.904904 5.194450 -1.933312  0.469974  0.510814  0.555686  0.468640 -0.036096
# 5.125565 2.549937 -1.974280  0.905762  0.164837  0.658199  0.421850  0.053575
# 8.480801 7.858174 -1.679912  0.977677  0.095650  0.869304  0.787055 -0.016087
# 1.189970 8.497401 -1.162066  0.384645  0.243402  0.529936  0.348253 -0.022373
# 7.689701 6.970272 -1.040695  0.322215  0.603383  0.183504  0.743769  0.044575
# 0.987496 4.400810 -1.793806  0.493743  0.347060  0.287821  0.900339 -0.008961
# 8.571008 6.449375 -1.197411  0.083243  0.484351  0.132957  0.366469 -0.016405
# 7.599809 7.505120 -1.570176  0.766237  0.549177  0.080261  0.976986  0.070690
#
#                          g4
# 7.355533 1.752923    stable
# 1.203128 4.944500  unstable
# 0.904904 5.194450    stable
# 5.125565 2.549937  unstable
# 8.480801 7.858174    stable
# 1.189970 8.497401    stable
# 7.689701 6.970272  unstable
# 0.987496 4.400810    stable
# 8.571008 6.449375    stable
# 7.599809 7.505120  unstable

# %% [markdown]
# # exploratory analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8000 entries, (6.600845341495937, 8.255091683706961) to (4.717312358556613, nan)
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    7643 non-null   float64
#  1   tau2    7628 non-null   float64
#  2   tau3    7601 non-null   float64
#  3   tau4    7630 non-null   float64
#  4   p1      7622 non-null   float64
#  5   p2      7624 non-null   float64
#  6   p3      7595 non-null   float64
#  7   p4      7566 non-null   float64
#  8   g1      7607 non-null   float64
#  9   g2      7593 non-null   float64
#  10  g3      8000 non-null   float64
#  11  g4      8000 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 1.4+ MB

# %%
df.describe().T
# Out:
#        count      mean       std        min       25%       50%       75%  \
# tau1  7643.0  5.286995  3.391827 -22.267166  2.875898  5.273493  7.654742
# tau2  7628.0  5.256773  3.369325 -22.088736  2.898912  5.241482  7.627580
# tau3  7601.0  3.757171  0.929822  -3.786337  3.212622  3.751241  4.288974
# tau4  7630.0 -1.244728  0.534012  -5.583676 -1.629052 -1.250355 -0.871899
# p1    7622.0 -1.252997  0.534087  -5.582606 -1.626393 -1.253065 -0.869397
# p2    7624.0 -1.246614  0.533955  -5.582577 -1.628507 -1.251692 -0.876095
# p3    7595.0  0.520385  0.337840  -2.217531  0.283486  0.520803  0.760711
# p4    7566.0  0.526093  0.338787  -2.221014  0.286657  0.526179  0.764101
# g1    7607.0  0.527766  0.337963  -2.215234  0.288777  0.526379  0.765836
# g2    7593.0  0.519195  0.338322  -2.221534  0.281147  0.519591  0.760128
# g3    8000.0  0.015477  0.036937  -0.080760 -0.015872  0.016806  0.044348
#
#             max
# tau1  32.784867
# tau2  32.599949
# tau3  11.291166
# tau4   3.083720
# p1     3.082862
# p2     3.080985
# p3     3.261391
# p4     3.270176
# g1     3.268532
# g2     3.265439
# g3     0.109403

# %%
df.hist(figsize=(12, 8), bins=30)
plt.suptitle("Grid stability dataset")
plt.tight_layout()
plt.show()

# %%
stable_counts = df["g4"].value_counts().sort_index()
stable_counts
# Out:
# g4
# stable      2927
# unstable    5073
# Name: count, dtype: int64

# %%
plt.figure()
surv_counts.plot(kind="bar")
plt.xlabel("stabila eller inte")
plt.ylabel("antal")
plt.title("Fördelning av stabila och icke stabila system")
plt.show()
